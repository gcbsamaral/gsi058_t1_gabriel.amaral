# %% [markdown]
# **Prática de Histogramas**

# %% [markdown]
# 0)	Código contendo as funções definidas para resolver todos os exercícios abaixo. É necessário executar a célula abaixo antes de qualquer outra.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def calculate_cdf(histogram):
    probabilities = histograma/np.sum(histograma)
    cdf = [probabilities[0]]
    for i in range(1, 256):
        cdf.append(probabilities[i]+cdf[i-1])
    
    return probabilities, cdf

def equalize_histogram(histogram):
    probabilities, cdf = calculate_cdf(histogram)
    new_levels = np.rint(255*cdf).astype(int)

    equalized_histogram = np.zeros(256)
    for i in range(256):
        equalized_histogram[new_levels[i]] += probabilities[i]
    
    return equalized_histogram

def generate_logarithmic_image(image):
    return 32*np.log2(imagem + 1)

# %% [markdown]
# 1)
# - Produza a imagem ‘negativa’ do arquivo ‘im_cells.png’
# - Com a imagem negativa, produza a imagem original novamente.
# - Mostre lado a lado a imagem original e a negativa. Em qual deles os objetos presentes na imagem são melhor percebidos? Justifique.
# - Aplique a imagem uma função logarítmica.

# %%
#Lê a imagem original
imagem = cv2.imread("im_cells.png", cv2.IMREAD_GRAYSCALE)

#Gera a imagem negativa
imagem_negativa = 255 - imagem

#Mostra a imagem gerada acima
plt.subplot(1, 2, 1)
plt.imshow(imagem_negativa, cmap='gray', vmin=0, vmax=255)
plt.title("Imagem Negativa")

#Gera a imagem original a partir da negativa
imagem_original_f_negativa = 255 - imagem_negativa

#Mostra a imagem gerada acima
plt.subplot(1, 2, 2)
plt.imshow(imagem_original_f_negativa, cmap='gray', vmin=0, vmax=255)
plt.title("Imagem Original f. negativa")

plt.show()

#Gera uma imagem a qual uma função logarítmica foi aplicada sob.
imagem_logaritmica = generate_logarithmic_image(imagem)

#Mostra a imagem gerada acima
plt.plot(1, 1, 1)
plt.imshow(imagem_logaritmica, cmap='gray', vmin=0, vmax=255)
plt.title("Imagem Logaritmitca")
plt.show()

# %% [markdown]
# 2)
# - Abra a imagem 'pout.tif' e mostre seu histograma.
# - Equalize a imagem anterior e mostre novamente seu histograma. Mostra a curva de transformação (consulte https://www.mathworks.com/help/images/histogram-equalization.html)
# (procurar função OpenCV)

# %%
#Lê a imagem original
imagem = cv2.imread("pout.tif", cv2.IMREAD_GRAYSCALE)

#Gera e plota o histograma da imagem original
plt.hist(imagem.flatten(), bins=256, range=[0,255], color="c", ec="black", lw=0.2)
plt.ylabel("Número de Pixels")
plt.xlabel("Valor dos Pixels")
plt.title("Histograma Imagem Original")
plt.show()

#Gera e plota o histogram da imagem equalizada gerada a partir da imagem original
[histograma,_,_] = plt.hist(cv2.equalizeHist(imagem).flatten(), bins=256, range=[0,255], color="c", ec="black", lw=0.2)
plt.ylabel("Número de Pixels")
plt.xlabel("Valor dos Pixels")
plt.title("Histograma Imagem Equalizada")
plt.show()

#Gera a distribuição de probabilidades acumuladas
[_,cdf] = calculate_cdf(histograma)

#Mostra a distribuição gerada acima
plt.plot(cdf, color="r")
plt.ylabel("Probabilidades")
plt.xlabel("Valor dos Pixels")
plt.title("Curva de Transformação")
plt.show()

# %% [markdown]
# 3) *Implemente* o algoritmo de equalização de histograma e aplique a imagem ‘imcells.png’. Use o mínimos de laços for - tente realizar operações diretas com matrizes e vetores do numpy
# - Aplique o mesmo algortimo 2x na mesma imagem e compare os resultados

# %%
#Lê a imagem original
imagem = cv2.imread("im_cells.png", cv2.IMREAD_GRAYSCALE)

#Gera e plota o histograma da imagem original
[histograma,_,_] = plt.hist(imagem.flatten(), bins=256, range=[0,255], color="c", ec="black", lw=0.2)
plt.ylabel("Número de Pixels")
plt.xlabel("Valor dos Pixels")
plt.title("Histograma Imagem Original")
plt.show()

#Gera e plota o histograma da imagem equalizada
plt.hist(equalize_histogram(histograma), bins=256, range=[0,255], color="c", ec="black", lw=0.2)
plt.ylabel("Número de Pixels")
plt.xlabel("Valor dos Pixels")
plt.title("Histograma Imagem Equalizada")
plt.show()

#Gera e plota o histograma da imagem equalizada
plt.hist(equalize_histogram(equalize_histogram(histograma)), bins=256, range=[0,255], color="c", ec="black", lw=0.2)
plt.ylabel("Número de Pixels")
plt.xlabel("Valor dos Pixels")
plt.title("Histograma Imagem Equalizada 2x sequenciais")
plt.show()
